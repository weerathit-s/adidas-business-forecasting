# %%
import pandas as pd
from datetime import date, timedelta
import datetime
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
import warnings

# %%
data = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/adidas%20quarterly%20sales.csv')
data
# Out:
#    Time Period  Revenue
# 0       2000Q1     1517
# 1       2000Q2     1248
# 2       2000Q3     1677
# 3       2000Q4     1393
# 4       2001Q1     1558
# ..         ...      ...
# 83      2020Q4     5142
# 84      2021Q1     5268
# 85      2021Q2     5077
# 86      2021Q3     5752
# 87      2021Q4     5137
#
# [88 rows x 2 columns]

# %%
data['Date'] = pd.to_datetime(data['Time Period'].str.replace(r'(Q\d) (\d+)', r'\2-\1'))
data
# Out:
# /var/folders/1y/fh4hqfb94nl1ck9n1lv83b5m0000gn/T/ipykernel_13994/558263993.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Date'] = pd.to_datetime(data['Time Period'].str.replace(r'(Q\d) (\d+)', r'\2-\1'))
#    Time Period  Revenue       Date
# 0       2000Q1     1517 2000-01-01
# 1       2000Q2     1248 2000-04-01
# 2       2000Q3     1677 2000-07-01
# 3       2000Q4     1393 2000-10-01
# 4       2001Q1     1558 2001-01-01
# ..         ...      ...        ...
# 83      2020Q4     5142 2020-10-01
# 84      2021Q1     5268 2021-01-01
# 85      2021Q2     5077 2021-04-01
# 86      2021Q3     5752 2021-07-01
# 87      2021Q4     5137 2021-10-01
#
# [88 rows x 3 columns]

# %%
data.set_index('Date', inplace=True)
del data['Time Period']
data
# Out:
#             Revenue
# Date
# 2000-01-01     1517
# 2000-04-01     1248
# 2000-07-01     1677
# 2000-10-01     1393
# 2001-01-01     1558
# ...             ...
# 2020-10-01     5142
# 2021-01-01     5268
# 2021-04-01     5077
# 2021-07-01     5752
# 2021-10-01     5137
#
# [88 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 10))
data['Revenue'].plot(ax=ax, label='Revenue')
plt.ylabel('Revenue')
ax.legend()

# %%
result = seasonal_decompose(data['Revenue'], 
                            model='multiplicative')
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 10)

# %%
pd.plotting.autocorrelation_plot(data['Revenue'])
# Out:
# <AxesSubplot: xlabel='Lag', ylabel='Autocorrelation'>

# %%
plot_pacf(data.Revenue, lags=20)
plt.show()
# Out:
# /Users/wee270641/miniforge3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# d = 0(stationary), 1(seasonal)
p, d, q = 5, 1, 2

# %%
model = sm.tsa.statespace.SARIMAX(data['Revenue'],
                                order=(p, d, q),
                                seasonal_order=(p, d, q, 12))
model = model.fit()
print(model.summary())
# Out:
# /Users/wee270641/miniforge3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /Users/wee270641/miniforge3/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           15     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.33485D+00    |proj g|=  1.93340D-01
#  This problem is unconstrained.
# At iterate    5    f=  6.25430D+00    |proj g|=  3.91119D-03
#
# At iterate   10    f=  6.25345D+00    |proj g|=  6.93400D-03
#
# At iterate   15    f=  6.25320D+00    |proj g|=  8.46355D-04
#
# At iterate   20    f=  6.25286D+00    |proj g|=  5.54402D-03
#
# At iterate   25    f=  6.25065D+00    |proj g|=  2.50280D-02
#
# At iterate   30    f=  6.24288D+00    |proj g|=  2.51467D-02
#
# At iterate   35    f=  6.23758D+00    |proj g|=  1.24076D-02
#
# At iterate   40    f=  6.23439D+00    |proj g|=  1.39255D-02
#
# At iterate   45    f=  6.23342D+00    |proj g|=  4.60566D-03
#
# At iterate   50    f=  6.23318D+00    |proj g|=  1.32901D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    15     50     56      1     0     0   1.329D-03   6.233D+00
#   F =   6.2331829476082561
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/wee270641/miniforge3/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            Revenue   No. Observations:                   88
# Model:             SARIMAX(5, 1, 2)x(5, 1, 2, 12)   Log Likelihood                -548.520
# Date:                            Thu, 27 Oct 2022   AIC                           1127.040
# Time:                                    21:27:48   BIC                           1161.803
# Sample:                                01-01-2000   HQIC                          1140.920
#                                      - 10-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5802      0.385     -4.100      0.000      -2.336      -0.825
# ar.L2         -1.4328      0.583     -2.459      0.014      -2.575      -0.291
# ar.L3         -0.8309      0.624     -1.331      0.183      -2.055       0.393
# ar.L4         -0.5186      0.824     -0.629      0.529      -2.134       1.097
# ar.L5         -0.2660      0.492     -0.541      0.589      -1.230       0.698
# ma.L1          1.5058      0.511      2.948      0.003       0.505       2.507
# ma.L2          0.9702      0.628      1.545      0.122      -0.260       2.201
# ar.S.L12      -1.1294    366.672     -0.003      0.998    -719.794     717.535
# ar.S.L24      -1.3451    317.738     -0.004      0.997    -624.100     621.409
# ar.S.L36      -0.7848    177.303     -0.004      0.996    -348.292     346.723
# ar.S.L48      -0.1852     51.145     -0.004      0.997    -100.428     100.057
# ar.S.L60      -0.0097      8.909     -0.001      0.999     -17.471      17.452
# ma.S.L12       0.3069    366.609      0.001      0.999    -718.234     718.848
# ma.S.L24       0.8615    223.851      0.004      0.997    -437.878     439.601
# sigma2      1.909e+05   3.97e+05      0.481      0.631   -5.88e+05    9.69e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               428.80
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.35   Skew:                            -2.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(16, 10))
plt.show()

# %%
predictions = model.predict(len(data), len(data)+12)
predictions
# Out:
# 2022-01-01    6078.555736
# 2022-04-01    5185.918425
# 2022-07-01    6293.195651
# 2022-10-01    5751.503801
# 2023-01-01    5911.592591
# 2023-04-01    5499.958715
# 2023-07-01    6389.260854
# 2023-10-01    5728.452284
# 2024-01-01    6322.865083
# 2024-04-01    5972.550533
# 2024-07-01    6648.281149
# 2024-10-01    6101.989399
# 2025-01-01    6697.153283
# Freq: QS-OCT, Name: predicted_mean, dtype: float64

# %%
data['Revenue'].plot(legend=True, 
                     label='Training Data', 
                     figsize=(16, 10))
predictions.plot(legend=True, label='Predictions')
# Out:
# <AxesSubplot: xlabel='Date'>
